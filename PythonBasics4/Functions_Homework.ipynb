# %% [markdown]
# ## Домашнее задание "Функции"
#
# ### 1. Основное задание

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

def create_list_of_docs(docs, shelves):
    list_of_docs = []
    for doc in docs:
        current_doc = doc.copy()
        for shelf in shelves:
            if current_doc['number'] in shelves[shelf]:
                current_doc.update({'directory': shelf})
                list_of_docs.append(current_doc)
    return list_of_docs

'''
user_command = 'p' # input("Введите команду: ")
document_no = '10006'
found_name = ''

for doc in list_of_docs:
    if ('number', document_no) in doc.items():
        found_name = doc['name']
        break

if found_name != '':
    print('Владелец документа:', found_name)
else:
    print('Документ не найден в базе')

#####################
user_command = 's'
document_no = '10006'
found_shelf = 0

for doc in list_of_docs:
    if ('number', document_no) in doc.items():
        found_shelf = doc['directory']
        break

if found_shelf != 0:
    print('Документ хранится на полке:', found_shelf)
else:
    print('Документ не найден в базе')

####################
user_command = 'l'

for doc in list_of_docs:
    print(f"№: {doc['number']}, тип: {doc['type']}, владелец: {doc['name']}, полка хранения: {doc['directory']}")

######################
user_command = 'as'
directory_no = '7'

if directory_no not in directories.keys():
    directories.update({directory_no: []})
    print('Полка добавлена')
else:
    print('Такая полка уже существует')
print('Текущий перечень полок:', ', '.join(list(directories.keys())))

##################
user_command = 'ds'
directory_no = '3'

if directory_no in directories.keys():
    if directories[directory_no] != []:
        print('На полке есть документа, удалите их перед удалением полки')
    else:
        del(directories[directory_no])
        print('Полка удалена.')
else:
    print('Такой полки не существует.')
print('Текущий перечень полок:', ', '.join(list(directories.keys())))
'''

def main():
    list_of_docs = create_list_of_docs(documents, directories)
    print(list_of_docs)
    # print(documents)
    return

main()
# Out:
# [{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин', 'directory': '1'}, {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов', 'directory': '1'}, {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов', 'directory': '2'}]
